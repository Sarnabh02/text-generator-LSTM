# %%
import torch
import torch.nn as nn
import torch.optim as optim
import string

# %%
import os
import random

def read_text_files(directory_path):
    all_text = ""
    for filename in os.listdir(directory_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(directory_path, filename)
            with open(file_path, "r") as file:
                all_text += file.read()
    return all_text

# Randomly generate 350 character string from the Stanford Large Movie Review Dataset
directory_path = "data/aclImdb/train/pos"
huge_string = read_text_files(directory_path)
print(len(huge_string))
char_ind = random.randint(0, 100000)

huge_string = huge_string[char_ind:char_ind+350]
# Out:
# 16839503

# %%
print(huge_string)
# Out:
# irsty Oakland zombie! Chaos and mayhem! I think it's more economical to eat your enemies than take vengeance in a drive-by, but then again, I'm a poor judge of the complexities of urban life. (How poor a judge? In response to a gory scene involving four men, I opined "Ah-ha! White t-shirts on everyone so the blood shows up. Economical! I used the s

# %%
# Define the dataset
data = huge_string
chars = string.printable

char_to_idx = {}
idx_to_char = {}

idx = 0
for i in chars:
    char_to_idx[i] = idx
    idx_to_char[idx] = i
    idx = idx + 1


data_indices = []
for ch in data:
    try:
        data_indices.append(char_to_idx[ch])
    except:
        pass

print(data_indices)
# Out:
# [18, 27, 28, 29, 34, 94, 50, 10, 20, 21, 10, 23, 13, 94, 35, 24, 22, 11, 18, 14, 62, 94, 38, 17, 10, 24, 28, 94, 10, 23, 13, 94, 22, 10, 34, 17, 14, 22, 62, 94, 44, 94, 29, 17, 18, 23, 20, 94, 18, 29, 68, 28, 94, 22, 24, 27, 14, 94, 14, 12, 24, 23, 24, 22, 18, 12, 10, 21, 94, 29, 24, 94, 14, 10, 29, 94, 34, 24, 30, 27, 94, 14, 23, 14, 22, 18, 14, 28, 94, 29, 17, 10, 23, 94, 29, 10, 20, 14, 94, 31, 14, 23, 16, 14, 10, 23, 12, 14, 94, 18, 23, 94, 10, 94, 13, 27, 18, 31, 14, 74, 11, 34, 73, 94, 11, 30, 29, 94, 29, 17, 14, 23, 94, 10, 16, 10, 18, 23, 73, 94, 44, 68, 22, 94, 10, 94, 25, 24, 24, 27, 94, 19, 30, 13, 16, 14, 94, 24, 15, 94, 29, 17, 14, 94, 12, 24, 22, 25, 21, 14, 33, 18, 29, 18, 14, 28, 94, 24, 15, 94, 30, 27, 11, 10, 23, 94, 21, 18, 15, 14, 75, 94, 69, 43, 24, 32, 94, 25, 24, 24, 27, 94, 10, 94, 19, 30, 13, 16, 14, 82, 94, 44, 23, 94, 27, 14, 28, 25, 24, 23, 28, 14, 94, 29, 24, 94, 10, 94, 16, 24, 27, 34, 94, 28, 12, 14, 23, 14, 94, 18, 23, 31, 24, 21, 31, 18, 23, 16, 94, 15, 24, 30, 27, 94, 22, 14, 23, 73, 94, 44, 94, 24, 25, 18, 23, 14, 13, 94, 63, 36, 17, 74, 17, 10, 62, 94, 58, 17, 18, 29, 14, 94, 29, 74, 28, 17, 18, 27, 29, 28, 94, 24, 23, 94, 14, 31, 14, 27, 34, 24, 23, 14, 94, 28, 24, 94, 29, 17, 14, 94, 11, 21, 24, 24, 13, 94, 28, 17, 24, 32, 28, 94, 30, 25, 75, 94, 40, 12, 24, 23, 24, 22, 18, 12, 10, 21, 62, 94, 44, 94, 30, 28, 14, 13, 94, 29, 17, 14, 94, 28]

# %%
# Defining inputs and Outputs
seq_length = 8
input_sequences = []
target_chars = []
print(len(data_indices))
print(seq_length)
print(len(data_indices) - seq_length)
diff = len(data_indices) - seq_length
for i in range(diff):
    input_sequences.append(data_indices[i:i + seq_length])
    print(data_indices[i:i + seq_length])
    target_chars.append(data_indices[i + seq_length])
    print(data_indices[i + seq_length])


    

# Convert input & outputs to tensors, so the model can interpret them
input_sequences = torch.tensor(input_sequences, dtype=torch.long)
target_chars = torch.tensor(target_chars, dtype=torch.long)

print(input_sequences)

print(target_chars)
# Out:
# 350
# 8
# 342
# [18, 27, 28, 29, 34, 94, 50, 10]
# 20
# [27, 28, 29, 34, 94, 50, 10, 20]
# 21
# [28, 29, 34, 94, 50, 10, 20, 21]
# 10
# [29, 34, 94, 50, 10, 20, 21, 10]
# 23
# [34, 94, 50, 10, 20, 21, 10, 23]
# 13
# [94, 50, 10, 20, 21, 10, 23, 13]
# 94
# [50, 10, 20, 21, 10, 23, 13, 94]
# 35
# [10, 20, 21, 10, 23, 13, 94, 35]
# 24
# [20, 21, 10, 23, 13, 94, 35, 24]
# 22
# [21, 10, 23, 13, 94, 35, 24, 22]
# 11
# [10, 23, 13, 94, 35, 24, 22, 11]
# 18
# [23, 13, 94, 35, 24, 22, 11, 18]
# 14
# [13, 94, 35, 24, 22, 11, 18, 14]
# 62
# [94, 35, 24, 22, 11, 18, 14, 62]
# 94
# [35, 24, 22, 11, 18, 14, 62, 94]
# 38
# [24, 22, 11, 18, 14, 62, 94, 38]
# 17
# [22, 11, 18, 14, 62, 94, 38, 17]
# 10
# [11, 18, 14, 62, 94, 38, 17, 10]
# 24
# [18, 14, 62, 94, 38, 17, 10, 24]
# 28
# [14, 62, 94, 38, 17, 10, 24, 28]
# 94
# [62, 94, 38, 17, 10, 24, 28, 94]
# 10
# [94, 38, 17, 10, 24, 28, 94, 10]
# 23
# [38, 17, 10, 24, 28, 94, 10, 23]
# 13
# [17, 10, 24, 28, 94, 10, 23, 13]
# 94
# [10, 24, 28, 94, 10, 23, 13, 94]
# 22
# [24, 28, 94, 10, 23, 13, 94, 22]
# 10
# [28, 94, 10, 23, 13, 94, 22, 10]
# 34
# [94, 10, 23, 13, 94, 22, 10, 34]
# 17
# [10, 23, 13, 94, 22, 10, 34, 17]
# 14
# [23, 13, 94, 22, 10, 34, 17, 14]
# 22
# [13, 94, 22, 10, 34, 17, 14, 22]
# 62
# [94, 22, 10, 34, 17, 14, 22, 62]
# 94
# [22, 10, 34, 17, 14, 22, 62, 94]
# 44
# [10, 34, 17, 14, 22, 62, 94, 44]
# 94
# [34, 17, 14, 22, 62, 94, 44, 94]
# 29
# [17, 14, 22, 62, 94, 44, 94, 29]
# 17
# [14, 22, 62, 94, 44, 94, 29, 17]
# 18
# [22, 62, 94, 44, 94, 29, 17, 18]
# 23
# [62, 94, 44, 94, 29, 17, 18, 23]
# 20
# [94, 44, 94, 29, 17, 18, 23, 20]
# 94
# [44, 94, 29, 17, 18, 23, 20, 94]
# 18
# [94, 29, 17, 18, 23, 20, 94, 18]
# 29
# [29, 17, 18, 23, 20, 94, 18, 29]
# 68
# [17, 18, 23, 20, 94, 18, 29, 68]
# 28
# [18, 23, 20, 94, 18, 29, 68, 28]
# 94
# [23, 20, 94, 18, 29, 68, 28, 94]
# 22
# [20, 94, 18, 29, 68, 28, 94, 22]
# 24
# [94, 18, 29, 68, 28, 94, 22, 24]
# 27
# [18, 29, 68, 28, 94, 22, 24, 27]
# 14
# [29, 68, 28, 94, 22, 24, 27, 14]
# 94
# [68, 28, 94, 22, 24, 27, 14, 94]
# 14
# [28, 94, 22, 24, 27, 14, 94, 14]
# 12
# [94, 22, 24, 27, 14, 94, 14, 12]
# 24
# [22, 24, 27, 14, 94, 14, 12, 24]
# 23
# [24, 27, 14, 94, 14, 12, 24, 23]
# 24
# [27, 14, 94, 14, 12, 24, 23, 24]
# 22
# [14, 94, 14, 12, 24, 23, 24, 22]
# 18
# [94, 14, 12, 24, 23, 24, 22, 18]
# 12
# [14, 12, 24, 23, 24, 22, 18, 12]
# 10
# [12, 24, 23, 24, 22, 18, 12, 10]
# 21
# [24, 23, 24, 22, 18, 12, 10, 21]
# 94
# [23, 24, 22, 18, 12, 10, 21, 94]
# 29
# [24, 22, 18, 12, 10, 21, 94, 29]
# 24
# [22, 18, 12, 10, 21, 94, 29, 24]
# 94
# [18, 12, 10, 21, 94, 29, 24, 94]
# 14
# [12, 10, 21, 94, 29, 24, 94, 14]
# 10
# [10, 21, 94, 29, 24, 94, 14, 10]
# 29
# [21, 94, 29, 24, 94, 14, 10, 29]
# 94
# [94, 29, 24, 94, 14, 10, 29, 94]
# 34
# [29, 24, 94, 14, 10, 29, 94, 34]
# 24
# [24, 94, 14, 10, 29, 94, 34, 24]
# 30
# [94, 14, 10, 29, 94, 34, 24, 30]
# 27
# [14, 10, 29, 94, 34, 24, 30, 27]
# 94
# [10, 29, 94, 34, 24, 30, 27, 94]
# 14
# [29, 94, 34, 24, 30, 27, 94, 14]
# 23
# [94, 34, 24, 30, 27, 94, 14, 23]
# 14
# [34, 24, 30, 27, 94, 14, 23, 14]
# 22
# [24, 30, 27, 94, 14, 23, 14, 22]
# 18
# [30, 27, 94, 14, 23, 14, 22, 18]
# 14
# [27, 94, 14, 23, 14, 22, 18, 14]
# 28
# [94, 14, 23, 14, 22, 18, 14, 28]
# 94
# [14, 23, 14, 22, 18, 14, 28, 94]
# 29
# [23, 14, 22, 18, 14, 28, 94, 29]
# 17
# [14, 22, 18, 14, 28, 94, 29, 17]
# 10
# [22, 18, 14, 28, 94, 29, 17, 10]
# 23
# [18, 14, 28, 94, 29, 17, 10, 23]
# 94
# [14, 28, 94, 29, 17, 10, 23, 94]
# 29
# [28, 94, 29, 17, 10, 23, 94, 29]
# 10
# [94, 29, 17, 10, 23, 94, 29, 10]
# 20
# [29, 17, 10, 23, 94, 29, 10, 20]
# 14
# [17, 10, 23, 94, 29, 10, 20, 14]
# 94
# [10, 23, 94, 29, 10, 20, 14, 94]
# 31
# [23, 94, 29, 10, 20, 14, 94, 31]
# 14
# [94, 29, 10, 20, 14, 94, 31, 14]
# 23
# [29, 10, 20, 14, 94, 31, 14, 23]
# 16
# [10, 20, 14, 94, 31, 14, 23, 16]
# 14
# [20, 14, 94, 31, 14, 23, 16, 14]
# 10
# [14, 94, 31, 14, 23, 16, 14, 10]
# 23
# [94, 31, 14, 23, 16, 14, 10, 23]
# 12
# [31, 14, 23, 16, 14, 10, 23, 12]
# 14
# [14, 23, 16, 14, 10, 23, 12, 14]
# 94
# [23, 16, 14, 10, 23, 12, 14, 94]
# 18
# [16, 14, 10, 23, 12, 14, 94, 18]
# 23
# [14, 10, 23, 12, 14, 94, 18, 23]
# 94
# [10, 23, 12, 14, 94, 18, 23, 94]
# 10
# [23, 12, 14, 94, 18, 23, 94, 10]
# 94
# [12, 14, 94, 18, 23, 94, 10, 94]
# 13
# [14, 94, 18, 23, 94, 10, 94, 13]
# 27
# [94, 18, 23, 94, 10, 94, 13, 27]
# 18
# [18, 23, 94, 10, 94, 13, 27, 18]
# 31
# [23, 94, 10, 94, 13, 27, 18, 31]
# 14
# [94, 10, 94, 13, 27, 18, 31, 14]
# 74
# [10, 94, 13, 27, 18, 31, 14, 74]
# 11
# [94, 13, 27, 18, 31, 14, 74, 11]
# 34
# [13, 27, 18, 31, 14, 74, 11, 34]
# 73
# [27, 18, 31, 14, 74, 11, 34, 73]
# 94
# [18, 31, 14, 74, 11, 34, 73, 94]
# 11
# [31, 14, 74, 11, 34, 73, 94, 11]
# 30
# [14, 74, 11, 34, 73, 94, 11, 30]
# 29
# [74, 11, 34, 73, 94, 11, 30, 29]
# 94
# [11, 34, 73, 94, 11, 30, 29, 94]
# 29
# [34, 73, 94, 11, 30, 29, 94, 29]
# 17
# [73, 94, 11, 30, 29, 94, 29, 17]
# 14
# [94, 11, 30, 29, 94, 29, 17, 14]
# 23
# [11, 30, 29, 94, 29, 17, 14, 23]
# 94
# [30, 29, 94, 29, 17, 14, 23, 94]
# 10
# [29, 94, 29, 17, 14, 23, 94, 10]
# 16
# [94, 29, 17, 14, 23, 94, 10, 16]
# 10
# [29, 17, 14, 23, 94, 10, 16, 10]
# 18
# [17, 14, 23, 94, 10, 16, 10, 18]
# 23
# [14, 23, 94, 10, 16, 10, 18, 23]
# 73
# [23, 94, 10, 16, 10, 18, 23, 73]
# 94
# [94, 10, 16, 10, 18, 23, 73, 94]
# 44
# [10, 16, 10, 18, 23, 73, 94, 44]
# 68
# [16, 10, 18, 23, 73, 94, 44, 68]
# 22
# [10, 18, 23, 73, 94, 44, 68, 22]
# 94
# [18, 23, 73, 94, 44, 68, 22, 94]
# 10
# [23, 73, 94, 44, 68, 22, 94, 10]
# 94
# [73, 94, 44, 68, 22, 94, 10, 94]
# 25
# [94, 44, 68, 22, 94, 10, 94, 25]
# 24
# [44, 68, 22, 94, 10, 94, 25, 24]
# 24
# [68, 22, 94, 10, 94, 25, 24, 24]
# 27
# [22, 94, 10, 94, 25, 24, 24, 27]
# 94
# [94, 10, 94, 25, 24, 24, 27, 94]
# 19
# [10, 94, 25, 24, 24, 27, 94, 19]
# 30
# [94, 25, 24, 24, 27, 94, 19, 30]
# 13
# [25, 24, 24, 27, 94, 19, 30, 13]
# 16
# [24, 24, 27, 94, 19, 30, 13, 16]
# 14
# [24, 27, 94, 19, 30, 13, 16, 14]
# 94
# [27, 94, 19, 30, 13, 16, 14, 94]
# 24
# [94, 19, 30, 13, 16, 14, 94, 24]
# 15
# [19, 30, 13, 16, 14, 94, 24, 15]
# 94
# [30, 13, 16, 14, 94, 24, 15, 94]
# 29
# [13, 16, 14, 94, 24, 15, 94, 29]
# 17
# [16, 14, 94, 24, 15, 94, 29, 17]
# 14
# [14, 94, 24, 15, 94, 29, 17, 14]
# 94
# [94, 24, 15, 94, 29, 17, 14, 94]
# 12
# [24, 15, 94, 29, 17, 14, 94, 12]
# 24
# [15, 94, 29, 17, 14, 94, 12, 24]
# 22
# [94, 29, 17, 14, 94, 12, 24, 22]
# 25
# [29, 17, 14, 94, 12, 24, 22, 25]
# 21
# [17, 14, 94, 12, 24, 22, 25, 21]
# 14
# [14, 94, 12, 24, 22, 25, 21, 14]
# 33
# [94, 12, 24, 22, 25, 21, 14, 33]
# 18
# [12, 24, 22, 25, 21, 14, 33, 18]
# 29
# [24, 22, 25, 21, 14, 33, 18, 29]
# 18
# [22, 25, 21, 14, 33, 18, 29, 18]
# 14
# [25, 21, 14, 33, 18, 29, 18, 14]
# 28
# [21, 14, 33, 18, 29, 18, 14, 28]
# 94
# [14, 33, 18, 29, 18, 14, 28, 94]
# 24
# [33, 18, 29, 18, 14, 28, 94, 24]
# 15
# [18, 29, 18, 14, 28, 94, 24, 15]
# 94
# [29, 18, 14, 28, 94, 24, 15, 94]
# 30
# [18, 14, 28, 94, 24, 15, 94, 30]
# 27
# [14, 28, 94, 24, 15, 94, 30, 27]
# 11
# [28, 94, 24, 15, 94, 30, 27, 11]
# 10
# [94, 24, 15, 94, 30, 27, 11, 10]
# 23
# [24, 15, 94, 30, 27, 11, 10, 23]
# 94
# [15, 94, 30, 27, 11, 10, 23, 94]
# 21
# [94, 30, 27, 11, 10, 23, 94, 21]
# 18
# [30, 27, 11, 10, 23, 94, 21, 18]
# 15
# [27, 11, 10, 23, 94, 21, 18, 15]
# 14
# [11, 10, 23, 94, 21, 18, 15, 14]
# 75
# [10, 23, 94, 21, 18, 15, 14, 75]
# 94
# [23, 94, 21, 18, 15, 14, 75, 94]
# 69
# [94, 21, 18, 15, 14, 75, 94, 69]
# 43
# [21, 18, 15, 14, 75, 94, 69, 43]
# 24
# [18, 15, 14, 75, 94, 69, 43, 24]
# 32
# [15, 14, 75, 94, 69, 43, 24, 32]
# 94
# [14, 75, 94, 69, 43, 24, 32, 94]
# 25
# [75, 94, 69, 43, 24, 32, 94, 25]
# 24
# [94, 69, 43, 24, 32, 94, 25, 24]
# 24
# [69, 43, 24, 32, 94, 25, 24, 24]
# 27
# [43, 24, 32, 94, 25, 24, 24, 27]
# 94
# [24, 32, 94, 25, 24, 24, 27, 94]
# 10
# [32, 94, 25, 24, 24, 27, 94, 10]
# 94
# [94, 25, 24, 24, 27, 94, 10, 94]
# 19
# [25, 24, 24, 27, 94, 10, 94, 19]
# 30
# [24, 24, 27, 94, 10, 94, 19, 30]
# 13
# [24, 27, 94, 10, 94, 19, 30, 13]
# 16
# [27, 94, 10, 94, 19, 30, 13, 16]
# 14
# [94, 10, 94, 19, 30, 13, 16, 14]
# 82
# [10, 94, 19, 30, 13, 16, 14, 82]
# 94
# [94, 19, 30, 13, 16, 14, 82, 94]
# 44
# [19, 30, 13, 16, 14, 82, 94, 44]
# 23
# [30, 13, 16, 14, 82, 94, 44, 23]
# 94
# [13, 16, 14, 82, 94, 44, 23, 94]
# 27
# [16, 14, 82, 94, 44, 23, 94, 27]
# 14
# [14, 82, 94, 44, 23, 94, 27, 14]
# 28
# [82, 94, 44, 23, 94, 27, 14, 28]
# 25
# [94, 44, 23, 94, 27, 14, 28, 25]
# 24
# [44, 23, 94, 27, 14, 28, 25, 24]
# 23
# [23, 94, 27, 14, 28, 25, 24, 23]
# 28
# [94, 27, 14, 28, 25, 24, 23, 28]
# 14
# [27, 14, 28, 25, 24, 23, 28, 14]
# 94
# [14, 28, 25, 24, 23, 28, 14, 94]
# 29
# [28, 25, 24, 23, 28, 14, 94, 29]
# 24
# [25, 24, 23, 28, 14, 94, 29, 24]
# 94
# [24, 23, 28, 14, 94, 29, 24, 94]
# 10
# [23, 28, 14, 94, 29, 24, 94, 10]
# 94
# [28, 14, 94, 29, 24, 94, 10, 94]
# 16
# [14, 94, 29, 24, 94, 10, 94, 16]
# 24
# [94, 29, 24, 94, 10, 94, 16, 24]
# 27
# [29, 24, 94, 10, 94, 16, 24, 27]
# 34
# [24, 94, 10, 94, 16, 24, 27, 34]
# 94
# [94, 10, 94, 16, 24, 27, 34, 94]
# 28
# [10, 94, 16, 24, 27, 34, 94, 28]
# 12
# [94, 16, 24, 27, 34, 94, 28, 12]
# 14
# [16, 24, 27, 34, 94, 28, 12, 14]
# 23
# [24, 27, 34, 94, 28, 12, 14, 23]
# 14
# [27, 34, 94, 28, 12, 14, 23, 14]
# 94
# [34, 94, 28, 12, 14, 23, 14, 94]
# 18
# [94, 28, 12, 14, 23, 14, 94, 18]
# 23
# [28, 12, 14, 23, 14, 94, 18, 23]
# 31
# [12, 14, 23, 14, 94, 18, 23, 31]
# 24
# [14, 23, 14, 94, 18, 23, 31, 24]
# 21
# [23, 14, 94, 18, 23, 31, 24, 21]
# 31
# [14, 94, 18, 23, 31, 24, 21, 31]
# 18
# [94, 18, 23, 31, 24, 21, 31, 18]
# 23
# [18, 23, 31, 24, 21, 31, 18, 23]
# 16
# [23, 31, 24, 21, 31, 18, 23, 16]
# 94
# [31, 24, 21, 31, 18, 23, 16, 94]
# 15
# [24, 21, 31, 18, 23, 16, 94, 15]
# 24
# [21, 31, 18, 23, 16, 94, 15, 24]
# 30
# [31, 18, 23, 16, 94, 15, 24, 30]
# 27
# [18, 23, 16, 94, 15, 24, 30, 27]
# 94
# [23, 16, 94, 15, 24, 30, 27, 94]
# 22
# [16, 94, 15, 24, 30, 27, 94, 22]
# 14
# [94, 15, 24, 30, 27, 94, 22, 14]
# 23
# [15, 24, 30, 27, 94, 22, 14, 23]
# 73
# [24, 30, 27, 94, 22, 14, 23, 73]
# 94
# [30, 27, 94, 22, 14, 23, 73, 94]
# 44
# [27, 94, 22, 14, 23, 73, 94, 44]
# 94
# [94, 22, 14, 23, 73, 94, 44, 94]
# 24
# [22, 14, 23, 73, 94, 44, 94, 24]
# 25
# [14, 23, 73, 94, 44, 94, 24, 25]
# 18
# [23, 73, 94, 44, 94, 24, 25, 18]
# 23
# [73, 94, 44, 94, 24, 25, 18, 23]
# 14
# [94, 44, 94, 24, 25, 18, 23, 14]
# 13
# [44, 94, 24, 25, 18, 23, 14, 13]
# 94
# [94, 24, 25, 18, 23, 14, 13, 94]
# 63
# [24, 25, 18, 23, 14, 13, 94, 63]
# 36
# [25, 18, 23, 14, 13, 94, 63, 36]
# 17
# [18, 23, 14, 13, 94, 63, 36, 17]
# 74
# [23, 14, 13, 94, 63, 36, 17, 74]
# 17
# [14, 13, 94, 63, 36, 17, 74, 17]
# 10
# [13, 94, 63, 36, 17, 74, 17, 10]
# 62
# [94, 63, 36, 17, 74, 17, 10, 62]
# 94
# [63, 36, 17, 74, 17, 10, 62, 94]
# 58
# [36, 17, 74, 17, 10, 62, 94, 58]
# 17
# [17, 74, 17, 10, 62, 94, 58, 17]
# 18
# [74, 17, 10, 62, 94, 58, 17, 18]
# 29
# [17, 10, 62, 94, 58, 17, 18, 29]
# 14
# [10, 62, 94, 58, 17, 18, 29, 14]
# 94
# [62, 94, 58, 17, 18, 29, 14, 94]
# 29
# [94, 58, 17, 18, 29, 14, 94, 29]
# 74
# [58, 17, 18, 29, 14, 94, 29, 74]
# 28
# [17, 18, 29, 14, 94, 29, 74, 28]
# 17
# [18, 29, 14, 94, 29, 74, 28, 17]
# 18
# [29, 14, 94, 29, 74, 28, 17, 18]
# 27
# [14, 94, 29, 74, 28, 17, 18, 27]
# 29
# [94, 29, 74, 28, 17, 18, 27, 29]
# 28
# [29, 74, 28, 17, 18, 27, 29, 28]
# 94
# [74, 28, 17, 18, 27, 29, 28, 94]
# 24
# [28, 17, 18, 27, 29, 28, 94, 24]
# 23
# [17, 18, 27, 29, 28, 94, 24, 23]
# 94
# [18, 27, 29, 28, 94, 24, 23, 94]
# 14
# [27, 29, 28, 94, 24, 23, 94, 14]
# 31
# [29, 28, 94, 24, 23, 94, 14, 31]
# 14
# [28, 94, 24, 23, 94, 14, 31, 14]
# 27
# [94, 24, 23, 94, 14, 31, 14, 27]
# 34
# [24, 23, 94, 14, 31, 14, 27, 34]
# 24
# [23, 94, 14, 31, 14, 27, 34, 24]
# 23
# [94, 14, 31, 14, 27, 34, 24, 23]
# 14
# [14, 31, 14, 27, 34, 24, 23, 14]
# 94
# [31, 14, 27, 34, 24, 23, 14, 94]
# 28
# [14, 27, 34, 24, 23, 14, 94, 28]
# 24
# [27, 34, 24, 23, 14, 94, 28, 24]
# 94
# [34, 24, 23, 14, 94, 28, 24, 94]
# 29
# [24, 23, 14, 94, 28, 24, 94, 29]
# 17
# [23, 14, 94, 28, 24, 94, 29, 17]
# 14
# [14, 94, 28, 24, 94, 29, 17, 14]
# 94
# [94, 28, 24, 94, 29, 17, 14, 94]
# 11
# [28, 24, 94, 29, 17, 14, 94, 11]
# 21
# [24, 94, 29, 17, 14, 94, 11, 21]
# 24
# [94, 29, 17, 14, 94, 11, 21, 24]
# 24
# [29, 17, 14, 94, 11, 21, 24, 24]
# 13
# [17, 14, 94, 11, 21, 24, 24, 13]
# 94
# [14, 94, 11, 21, 24, 24, 13, 94]
# 28
# [94, 11, 21, 24, 24, 13, 94, 28]
# 17
# [11, 21, 24, 24, 13, 94, 28, 17]
# 24
# [21, 24, 24, 13, 94, 28, 17, 24]
# 32
# [24, 24, 13, 94, 28, 17, 24, 32]
# 28
# [24, 13, 94, 28, 17, 24, 32, 28]
# 94
# [13, 94, 28, 17, 24, 32, 28, 94]
# 30
# [94, 28, 17, 24, 32, 28, 94, 30]
# 25
# [28, 17, 24, 32, 28, 94, 30, 25]
# 75
# [17, 24, 32, 28, 94, 30, 25, 75]
# 94
# [24, 32, 28, 94, 30, 25, 75, 94]
# 40
# [32, 28, 94, 30, 25, 75, 94, 40]
# 12
# [28, 94, 30, 25, 75, 94, 40, 12]
# 24
# [94, 30, 25, 75, 94, 40, 12, 24]
# 23
# [30, 25, 75, 94, 40, 12, 24, 23]
# 24
# [25, 75, 94, 40, 12, 24, 23, 24]
# 22
# [75, 94, 40, 12, 24, 23, 24, 22]
# 18
# [94, 40, 12, 24, 23, 24, 22, 18]
# 12
# [40, 12, 24, 23, 24, 22, 18, 12]
# 10
# [12, 24, 23, 24, 22, 18, 12, 10]
# 21
# [24, 23, 24, 22, 18, 12, 10, 21]
# 62
# [23, 24, 22, 18, 12, 10, 21, 62]
# 94
# [24, 22, 18, 12, 10, 21, 62, 94]
# 44
# [22, 18, 12, 10, 21, 62, 94, 44]
# 94
# [18, 12, 10, 21, 62, 94, 44, 94]
# 30
# [12, 10, 21, 62, 94, 44, 94, 30]
# 28
# [10, 21, 62, 94, 44, 94, 30, 28]
# 14
# [21, 62, 94, 44, 94, 30, 28, 14]
# 13
# [62, 94, 44, 94, 30, 28, 14, 13]
# 94
# [94, 44, 94, 30, 28, 14, 13, 94]
# 29
# [44, 94, 30, 28, 14, 13, 94, 29]
# 17
# [94, 30, 28, 14, 13, 94, 29, 17]
# 14
# [30, 28, 14, 13, 94, 29, 17, 14]
# 94
# [28, 14, 13, 94, 29, 17, 14, 94]
# 28
# tensor([[18, 27, 28,  ..., 94, 50, 10],
#         [27, 28, 29,  ..., 50, 10, 20],
#         [28, 29, 34,  ..., 10, 20, 21],
#         ...,
#         [94, 30, 28,  ..., 94, 29, 17],
#         [30, 28, 14,  ..., 29, 17, 14],
#         [28, 14, 13,  ..., 17, 14, 94]])
# tensor([20, 21, 10, 23, 13, 94, 35, 24, 22, 11, 18, 14, 62, 94, 38, 17, 10, 24,
#         28, 94, 10, 23, 13, 94, 22, 10, 34, 17, 14, 22, 62, 94, 44, 94, 29, 17,
#         18, 23, 20, 94, 18, 29, 68, 28, 94, 22, 24, 27, 14, 94, 14, 12, 24, 23,
#         24, 22, 18, 12, 10, 21, 94, 29, 24, 94, 14, 10, 29, 94, 34, 24, 30, 27,
#         94, 14, 23, 14, 22, 18, 14, 28, 94, 29, 17, 10, 23, 94, 29, 10, 20, 14,
#         94, 31, 14, 23, 16, 14, 10, 23, 12, 14, 94, 18, 23, 94, 10, 94, 13, 27,
#         18, 31, 14, 74, 11, 34, 73, 94, 11, 30, 29, 94, 29, 17, 14, 23, 94, 10,
#         16, 10, 18, 23, 73, 94, 44, 68, 22, 94, 10, 94, 25, 24, 24, 27, 94, 19,
#         30, 13, 16, 14, 94, 24, 15, 94, 29, 17, 14, 94, 12, 24, 22, 25, 21, 14,
#         33, 18, 29, 18, 14, 28, 94, 24, 15, 94, 30, 27, 11, 10, 23, 94, 21, 18,
#         15, 14, 75, 94, 69, 43, 24, 32, 94, 25, 24, 24, 27, 94, 10, 94, 19, 30,
#         13, 16, 14, 82, 94, 44, 23, 94, 27, 14, 28, 25, 24, 23, 28, 14, 94, 29,
#         24, 94, 10, 94, 16, 24, 27, 34, 94, 28, 12, 14, 23, 14, 94, 18, 23, 31,
#         24, 21, 31, 18, 23, 16, 94, 15, 24, 30, 27, 94, 22, 14, 23, 73, 94, 44,
#         94, 24, 25, 18, 23, 14, 13, 94, 63, 36, 17, 74, 17, 10, 62, 94, 58, 17,
#         18, 29, 14, 94, 29, 74, 28, 17, 18, 27, 29, 28, 94, 24, 23, 94, 14, 31,
#         14, 27, 34, 24, 23, 14, 94, 28, 24, 94, 29, 17, 14, 94, 11, 21, 24, 24,
#         13, 94, 28, 17, 24, 32, 28, 94, 30, 25, 75, 94, 40, 12, 24, 23, 24, 22,
#         18, 12, 10, 21, 62, 94, 44, 94, 30, 28, 14, 13, 94, 29, 17, 14, 94, 28])

# %%
class LSTMLanguageModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMLanguageModel, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq):
        embedded = self.embedding(input_seq)
        output, _ = self.lstm(embedded)
        prediction = self.fc(output[:, -1, :])
        return prediction

# %%
input_size = len(chars)
hidden_size = 256
output_size = len(chars)
learning_rate = 0.01
num_epochs = 2000

# Initialization
model = LSTMTagger(input_size, hidden_size, output_size)
loss_f = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Training 
for epoch in range(num_epochs):
    optimizer.zero_grad()
    outputs = model(input_sequences)
    loss = loss_f(outputs, target_chars)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 100 == 0:
        print(f"Epoch {epoch+1}")
# Out:
# Epoch 100
# Epoch 200
# Epoch 300
# Epoch 400
# Epoch 500
# Epoch 600
# Epoch 700
# Epoch 800
# Epoch 900
# Epoch 1000
# Epoch 1100
# Epoch 1200
# Epoch 1300
# Epoch 1400
# Epoch 1500
# Epoch 1600
# Epoch 1700
# Epoch 1800
# Epoch 1900
# Epoch 2000

# %%
#Test it Out!

num_chars_desired = 20


seed_text = "I think it's "
generated_text = seed_text
with torch.no_grad():
    for _ in range(num_chars_desired):
        input_seq = torch.tensor([char_to_idx[ch] for ch in seed_text], dtype=torch.long).view(1, -1)
        prediction = model(input_seq)
        _, next_char_idx = torch.max(prediction, 1)
        next_char = idx_to_char[next_char_idx.item()]
        generated_text += next_char
        seed_text = seed_text[1:] + next_char

print("Output:")
print(generated_text)
# Out:
# Output:
# I think it's more economical to e
